# %%
import json

path = '../data/weather_data.json'
import pandas as pd
import json

# %%
with open(path) as f:
    data = json.load(f)

df = pd.json_normalize(data)
df.head()
# Out:
#                                              weather      base  visibility  \
# 0  [{'id': 802, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone       id       name  cod  coord.lon  coord.lat  ...  \
# 0  1776261262    -10800  3448439  São Paulo  200   -46.6361   -23.5475  ...
#
#    main.humidity  main.sea_level  main.grnd_level  wind.speed  wind.deg  \
# 0             56            1019              929        3.43        99
#
#    wind.gust  clouds.all  sys.country  sys.sunrise  sys.sunset
# 0       3.54          36           BR   1776244795  1776286368
#
# [1 rows x 25 columns]

# %%
df.info()
